# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Karla Anton ,
#              Anehi Karely Mayorquin.
#
# **Fecha:** 06 de octubre del 2020.
#
# **Expediente** : Karely = if707468 , Karla= if714572.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Tarea 4: Clase 10
#
# Link: https://github.com/anehik/ProyectoConjunto_AKMayorquin_KAnton

# %% [markdown]
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %%
#Librerías
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Solución Karla
# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False)) #El opt te da el maximo, y la f del principio es para evaluar f con 
t = lambda x: max_f*np.sin(np.pi*x)
x = np.arange(0,1,.01)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# %%
#Solución Karely
# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False)) #El opt te da el maximo, y la f del principio es para evaluar f con 
t = lambda x: max_f*np.sin(np.pi*x)
x = np.arange(0,1,.01)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# %% [markdown]
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# #### Solución Karla
# $$g(x)=\frac{t(x)}{c}$$ donde $$c=\int_{-\infty}^{\infty}t(x)dx$$
#
# Primero obtenemos $$\int_{a}^{b}t(x)dx$$
# donde $a=0$ y $b=1$
# $$\int_{0}^{1}t(x)dx = \int_{0}^{1}a\sin(\pi x)dx= \frac{-a\cos(\pi x)}{\pi}|_{0}^{1} = -\frac{a\cos(\pi)}{\pi}+ \frac{a\cos(0)}{\pi} = \frac{a}{\pi}+\frac{a}{\pi}=\frac{2a}{\pi}$$
# Por lo tanto
# $$g(x)=\frac{a\sin{\pi x}}{\frac{2a}{\pi}}=\frac{\pi\sin(\pi x)}{2}$$

# %% [markdown]
# #### Solución Karely
# $$g(x)=\frac{t(x)}{c}$$ donde $$c=\int_{-\infty}^{\infty}t(x)dx$$
#
# Primero obtenemos $$\int_{a}^{b}t(x)dx$$
# donde $a=0$ y $b=1$
# $$\int_{0}^{1}t(x)dx = \int_{0}^{1}a\sin(\pi x)dx= \frac{-a\cos(\pi x)}{\pi}|_{0}^{1} = -\frac{a\cos(\pi)}{\pi}+ \frac{a\cos(0)}{\pi} = \frac{a}{\pi}+\frac{a}{\pi}=\frac{2a}{\pi}$$
# Por lo tanto
# $$g(x)=\frac{a\sin{\pi x}}{\frac{2a}{\pi}}=\frac{\pi\sin(\pi x)}{2}$$

# %% [markdown]
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# #### Solución Karla
# $$G(x)=\int_{0}^{x}\frac{\pi\sin(\pi x)}{2} = -\frac{cos(\pi x)}{2}\Big|_{0}^{x}=-\frac{\cos(\pi x)}{2}+\frac{1}{2}$$
# Igualamos $G(x)$ a $U$
# $$U=-\frac{\cos(\pi x)}{2}+\frac{1}{2}$$
# $$2U=-\cos(\pi x)+1$$
# $$2U-1=-\cos(\pi x)$$
# $$-\cos(2U-1)=\pi x$$
# $$x=\frac{\cos^{-1}(-2U+1)}{\pi}$$
# Este valor corresponde a $R_2$ que sigue una distribución $g(x)$

# %% [markdown]
# #### Solución Karely
# $$G(x)=\int_{0}^{x}\frac{\pi\sin(\pi x)}{2} = -\frac{cos(\pi x)}{2}\Big|_{0}^{x}=-\frac{\cos(\pi x)}{2}+\frac{1}{2}$$
# Igualamos $G(x)$ a $U$
# $$U=-\frac{\cos(\pi x)}{2}+\frac{1}{2}$$
# $$2U=-\cos(\pi x)+1$$
# $$2U-1=-\cos(\pi x)$$
# $$-\cos(2U-1)=\pi x$$
# $$x=\frac{\cos^{-1}(-2U+1)}{\pi}$$
# Este valor corresponde a $R_2$ que sigue una distribución $g(x)$

# %% [markdown]
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
# ![image.png](attachment:image.png)

# %%
#Solución Karla
g = lambda x: np.pi*np.sin(np.pi*x)/2
x = np.arange(0,1,.01)
R2 = lambda u: np.arccos(1-2*u)/np.pi
N = 10000
U = np.random.rand(N)
z = R2(U)

plt.plot(x,g(x),label='g(x)')
plt.hist(z,bins=50,density=True)
plt.legend()

# %%
#Solución Karely
g = lambda x: np.pi*np.sin(np.pi*x)/2
x = np.arange(0,1,.01)
R2 = lambda u: np.arccos(1-2*u)/np.pi
N = 10000
U = np.random.rand(N)
z = R2(U)

plt.plot(x,g(x),label='g(x)')
plt.hist(z,bins=50,density=True)
plt.legend()

# %% [markdown]
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![image2.png](attachment:image2.png)

# %%
#Solución Karla
def Acep_rechazo(R2:'Variables distribuidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'Función objetivo a generar',
                 t:'Función que mayor a f'):
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))

t = lambda x: max_f*np.sin(np.pi*x)

x = np.arange(0,1,0.01)
print('Máximo de f:',max_f)

plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

N = 500 
R_2 = lambda u: np.arccos(1-2*u)/np.pi
U = np.random.rand(N)
z = R_2(U)
R2 = z  
R1 = np.random.rand(N)

Acep_rechazo(R2,R1,f,t)
# Out:
# Máximo de f: [1.875]

# %%
#Solución Karely
def Acep_rechazo(R2:'Variables distribuidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'Función objetivo a generar',
                 t:'Función que mayor a f'):
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))

t = lambda x: max_f*np.sin(np.pi*x)

x = np.arange(0,1,0.01)
print('Máximo de f:',max_f)

plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

N = 500 
R_2 = lambda u: np.arccos(1-2*u)/np.pi
U = np.random.rand(N)
z = R_2(U)
R2 = z  
R1 = np.random.rand(N)

Acep_rechazo(R2,R1,f,t)
# Out:
# Máximo de f: [1.875]

# %% [markdown]
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %%
#Solución Karla
def Acep(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#    R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    d = np.zeros(len(R1))
    condition = np.multiply(R2,t_x)<=f_x
    d = np.asarray([1 if condition[i] else 0 for i in range(len(R1))]).sum()
    return d

# %%
f = lambda x:30*(x**2-2*x**3+x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
#el resultado. 
# Función t -> Función constante
ts = lambda x: max_f*np.sin(np.pi*x)
tc = lambda x: max_f*np.ones(len(x))
x = np.arange(0,1,0.01)

N = 500
R_2 = lambda u: np.arccos(1-2*u)/np.pi
U = np.random.rand(N)
z = R_2(U)
R2 = z
R1 = np.random.rand(N)

# %%
Aceptacion_Sc = Acep(R2,R1,f,tc)*100/len(R1)
Aceptacion_Ss = Acep(R2,R1,f,ts)*100/len(R1)
print('Porcentaje de puntos de aceptación cuando usas t(x) como constante:  ',Aceptacion_Sc,'%')
print('Porcentaje de puntos de aceptación cuando usas t(x) como un pulso senoidal: ',Aceptacion_Ss,'%')
# Out:
# Porcentaje de puntos de aceptación cuando usas t(x) como constante:   53.6 %
# Porcentaje de puntos de aceptación cuando usas t(x) como un pulso senoidal:  62.6 %

# %%
#Solución Karely
def Acep(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#    R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    d = np.zeros(len(R1))
    condition = np.multiply(R2,t_x)<=f_x
    d = np.asarray([1 if condition[i] else 0 for i in range(len(R1))]).sum()
    return d

f = lambda x:30*(x**2-2*x**3+x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
#el resultado. 
# Función t -> Función constante
ts = lambda x: max_f*np.sin(np.pi*x)
tc = lambda x: max_f*np.ones(len(x))
x = np.arange(0,1,0.01)

N = 500
R_2 = lambda u: np.arccos(1-2*u)/np.pi
U = np.random.rand(N)
z = R_2(U)
R2 = z
R1 = np.random.rand(N)
Aceptacion_Sc = Acep(R2,R1,f,tc)*100/len(R1)
Aceptacion_Ss = Acep(R2,R1,f,ts)*100/len(R1)
print('Porcentaje de puntos de aceptación cuando usas t(x) como constante:  ',Aceptacion_Sc,'%')
print('Porcentaje de puntos de aceptación cuando usas t(x) como un pulso senoidal: ',Aceptacion_Ss,'%')
# Out:
# Porcentaje de puntos de aceptación cuando usas t(x) como constante:   50.6 %
# Porcentaje de puntos de aceptación cuando usas t(x) como un pulso senoidal:  71.8 %

# %% [markdown]
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %%
#Solución Karla
f = lambda x: 20*x*(1-x)**3
a = f(optimize.fmin(lambda x:-f(x),5,disp=False))
t = lambda x: a*np.ones(len(x))
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend(loc="best")
N= 500
R2 = np.random.rand(N)
R1 = np.random.rand(N)
Acep_rechazo(R1, R2, f, t)

# %%
#Solución Karely
f = lambda x: 20*x*(1-x)**3
a = f(optimize.fmin(lambda x:-f(x),5,disp=False))
t = lambda x: a*np.ones(len(x))
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend(loc="best")
N= 500
R2 = np.random.rand(N)
R1 = np.random.rand(N)
Acep_rechazo(R1, R2, f, t)
